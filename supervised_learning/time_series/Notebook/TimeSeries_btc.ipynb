# %%
#!/usr/bin/env python3
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

def load_time_series_data(file_path):
    """Load time series data from a CSV file."""
    data = pd.read_csv(file_path, index_col='Timestamp')
    data.index = pd.to_datetime(data.index, unit='s')
    data.sort_index(inplace=True)
    data = data.dropna(how='all')
    print("DataFrame Info:")
    data.info()
    print("\nDataFrame Head:")
    print(data.head())
    plot_col = ['Low', 'High', 'Volume_(BTC)', 'Volume_(Currency)']
    plot_feat = data[plot_col]
    plot_feat.index = data.index
    plot_feat.plot(subplots=True)
    plt.show()

# %%
load_time_series_data('/content/data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv.zip')
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1990691 entries, 2014-12-01 05:33:00 to 2019-01-07 22:06:00
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Open               float64
#  1   High               float64
#  2   Low                float64
#  3   Close              float64
#  4   Volume_(BTC)       float64
#  5   Volume_(Currency)  float64
#  6   Weighted_Price     float64
# dtypes: float64(7)
# memory usage: 121.5 MB
#
# DataFrame Head:
#                       Open   High    Low  Close  Volume_(BTC)  \
# Timestamp
# 2014-12-01 05:33:00  300.0  300.0  300.0  300.0      0.010000
# 2014-12-01 05:40:00  300.0  300.0  300.0  300.0      0.010000
# 2014-12-01 06:24:00  370.0  370.0  370.0  370.0      0.010000
# 2014-12-01 06:50:00  370.0  370.0  370.0  370.0      0.026556
# 2014-12-02 05:29:00  377.0  377.0  377.0  377.0      0.010000
#
#                      Volume_(Currency)  Weighted_Price
# Timestamp
# 2014-12-01 05:33:00            3.00000           300.0
# 2014-12-01 05:40:00            3.00000           300.0
# 2014-12-01 06:24:00            3.70000           370.0
# 2014-12-01 06:50:00            9.82555           370.0
# 2014-12-02 05:29:00            3.77000           377.0
